# %% [markdown]
# **Objective**: Use perceiver IO model code in a colab for an interesting ml task
#
# Source:
# * https://colab.research.google.com/github/2796gaurav/code_examples/blob/main/Perceiver/Perceiver_masked_language_modelling.ipynb#scrollTo=ipZs6p0Xk3lb
# * https://medium.com/analytics-vidhya/perceiver-io-a-general-architecture-for-structured-inputs-outputs-4ad669315e7f

# %%
# !pip install dm-haiku
# !pip install einops

# !mkdir /content/perceiver
# !touch /content/perceiver/__init__.py
# !wget -O /content/perceiver/bytes_tokenizer.py https://raw.githubusercontent.com/deepmind/deepmind-research/master/perceiver/bytes_tokenizer.py
# !wget -O /content/perceiver/io_processors.py https://raw.githubusercontent.com/deepmind/deepmind-research/master/perceiver/io_processors.py
# !wget -O /content/perceiver/perceiver.py https://raw.githubusercontent.com/deepmind/deepmind-research/master/perceiver/perceiver.py
# !wget -O /content/perceiver/position_encoding.py https://raw.githubusercontent.com/deepmind/deepmind-research/master/perceiver/position_encoding.py
# Out:
# Collecting dm-haiku
#   Downloading dm_haiku-0.0.4-py3-none-any.whl (284 kB)
#      |████████████████████████████████| 284 kB 3.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from dm-haiku) (3.7.4.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from dm-haiku) (0.8.9)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from dm-haiku) (0.12.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from dm-haiku) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.7.1->dm-haiku) (1.15.0)
# Installing collected packages: dm-haiku
# Successfully installed dm-haiku-0.0.4
# Collecting einops
#   Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Installing collected packages: einops
# Successfully installed einops-0.3.2
# --2021-10-07 02:22:01--  https://raw.githubusercontent.com/deepmind/deepmind-research/master/perceiver/bytes_tokenizer.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1850 (1.8K) [text/plain]
# Saving to: ‘/content/perceiver/bytes_tokenizer.py’
#
# /content/perceiver/ 100%[===================>]   1.81K  --.-KB/s    in 0s
#
# 2021-10-07 02:22:01 (14.2 MB/s) - ‘/content/perceiver/bytes_tokenizer.py’ saved [1850/1850]
#
# --2021-10-07 02:22:01--  https://raw.githubusercontent.com/deepmind/deepmind-research/master/perceiver/io_processors.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29359 (29K) [text/plain]
# Saving to: ‘/content/perceiver/io_processors.py’
#
# /content/perceiver/ 100%[===================>]  28.67K  --.-KB/s    in 0.003s
#
# 2021-10-07 02:22:02 (8.69 MB/s) - ‘/content/perceiver/io_processors.py’ saved [29359/29359]
#
# --2021-10-07 02:22:02--  https://raw.githubusercontent.com/deepmind/deepmind-research/master/perceiver/perceiver.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30179 (29K) [text/plain]
# Saving to: ‘/content/perceiver/perceiver.py’
#
# /content/perceiver/ 100%[===================>]  29.47K  --.-KB/s    in 0.003s
#
# 2021-10-07 02:22:02 (9.43 MB/s) - ‘/content/perceiver/perceiver.py’ saved [30179/30179]
#
# --2021-10-07 02:22:02--  https://raw.githubusercontent.com/deepmind/deepmind-research/master/perceiver/position_encoding.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8107 (7.9K) [text/plain]
# Saving to: ‘/content/perceiver/position_encoding.py’
#
# /content/perceiver/ 100%[===================>]   7.92K  --.-KB/s    in 0s
#
# 2021-10-07 02:22:03 (43.9 MB/s) - ‘/content/perceiver/position_encoding.py’ saved [8107/8107]

# %%
from typing import Union

import haiku as hk
import jax
import jax.numpy as jnp
import numpy as np
import pandas as pd
import pickle

from perceiver import perceiver, position_encoding, io_processors, bytes_tokenizer

# %%
# !wget -O language_perceiver_io_bytes.pickle https://storage.googleapis.com/perceiver_io/language_perceiver_io_bytes.pickle

with open("language_perceiver_io_bytes.pickle", "rb") as f:
  params = pickle.loads(f.read())
# Out:
# --2021-10-07 02:22:06--  https://storage.googleapis.com/perceiver_io/language_perceiver_io_bytes.pickle
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.97.128, 108.177.125.128, 142.251.8.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.97.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 804479532 (767M) [application/octet-stream]
# Saving to: ‘language_perceiver_io_bytes.pickle’
#
# language_perceiver_ 100%[===================>] 767.21M  35.9MB/s    in 25s
#
# 2021-10-07 02:22:33 (30.9 MB/s) - ‘language_perceiver_io_bytes.pickle’ saved [804479532/804479532]

# %% [markdown]
# # Text Dataset
# Using Kaggle [Quotes Dataset](https://www.kaggle.com/akmittal/quotes-dataset) provided by user Amit Mittal
#
# **Perceiver IO task**: To predict the last word (masked) for 36,937 quotes

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
! kaggle datasets download -d akmittal/quotes-dataset
# Out:
# Downloading quotes-dataset.zip to /content
#   0% 0.00/3.88M [00:00<?, ?B/s]
# 100% 3.88M/3.88M [00:00<00:00, 64.4MB/s]

# %%
! unzip quotes-dataset
# Out:
# Archive:  quotes-dataset.zip
#   inflating: quotes.json

# %% [markdown]
# ## Preprocessing

# %%
df_quote = pd.read_json('quotes.json')
total_q = 1000
df_quote = df_quote['Quote'].unique()[:total_q]
print("Number of quotes =", total_q)
df_quote[:5]
# Out:
# Number of quotes = 1000
# array(["Don't cry because it's over, smile because it happened.",
#        "I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.",
#        'Be yourself; everyone else is already taken.',
#        "Two things are infinite: the universe and human stupidity; and I'm not sure about the universe.",
#        "Be who you are and say what you feel, because those who mind don't matter, and those who matter don't mind."],
#       dtype=object)

# %%
df_quote_incomplete = []
missing_index = [] # stored length of missing word for slicing later
missing_word = []
for text in df_quote:
    missing_word.append(text.split(" ")[-1])
    text_preprocessed = text.split(" ")[:-1]
    incomplete_text = " ".join(text_preprocessed)
    missing_index.append(len(text) - len(incomplete_text))
    df_quote_incomplete.append(incomplete_text)

# %%
df_quote_incomplete[:5]
# Out:
# ["Don't cry because it's over, smile because it",
#  "I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my",
#  'Be yourself; everyone else is already',
#  "Two things are infinite: the universe and human stupidity; and I'm not sure about the",
#  "Be who you are and say what you feel, because those who mind don't matter, and those who matter don't"]

# %% [markdown]
# # Model Config

# %% [markdown]
# ## Encoder and Decoder

# %%
D_MODEL = 768
D_LATENTS = 1280
MAX_SEQ_LEN = 2048

encoder_config = dict(
    num_self_attends_per_block=26,
    num_blocks=1,
    z_index_dim=256,
    num_z_channels=D_LATENTS,
    num_self_attend_heads=8,
    num_cross_attend_heads=8,
    qk_channels=8 * 32,
    v_channels=D_LATENTS,
    use_query_residual=True,
    cross_attend_widening_factor=1,
    self_attend_widening_factor=1)

decoder_config = dict(
    output_num_channels=D_LATENTS,
    position_encoding_type='trainable',
    output_index_dims=MAX_SEQ_LEN,
    num_z_channels=D_LATENTS,
    qk_channels=8 * 32,
    v_channels=D_MODEL,
    num_heads=8,
    final_project=False,
    use_query_residual=False,
    trainable_position_encoding_kwargs=dict(num_channels=D_MODEL))

# %% [markdown]
# ## Decoding Perceiver Model

# %%
def apply_perceiver(
    inputs: jnp.ndarray, input_mask: jnp.ndarray) -> jnp.ndarray:
  """Runs a forward pass on the Perceiver.

  Args:
    inputs: input bytes, an int array of shape [B, T]
    input_mask: Array of shape indicating which entries are valid and which are
      masked. A truthy value indicates that the entry is valid.

  Returns:
    The output logits, an array of shape [B, T, vocab_size].
  """
  assert inputs.shape[1] == MAX_SEQ_LEN

  embedding_layer = hk.Embed(
      vocab_size=tokenizer.vocab_size,
      embed_dim=D_MODEL)
  embedded_inputs = embedding_layer(inputs)

  batch_size = embedded_inputs.shape[0]

  input_pos_encoding = perceiver.position_encoding.TrainablePositionEncoding(
      index_dim=MAX_SEQ_LEN, num_channels=D_MODEL)
  embedded_inputs = embedded_inputs + input_pos_encoding(batch_size)
  perceiver_mod = perceiver.Perceiver(
      encoder=perceiver.PerceiverEncoder(**encoder_config),
      decoder=perceiver.BasicDecoder(**decoder_config))
  output_embeddings = perceiver_mod(
      embedded_inputs, is_training=False, input_mask=input_mask, query_mask=input_mask)

  logits = io_processors.EmbeddingDecoder(
      embedding_matrix=embedding_layer.embeddings)(output_embeddings)
  return logits

apply_perceiver = hk.transform(apply_perceiver).apply

# %% [markdown]
# ## Masked text

# %%
# Pad each quotes to the same length
def pad(max_sequence_length: int, inputs, input_mask):
  input_len = inputs.shape[1]
  assert input_len <= max_sequence_length
  pad_len = max_sequence_length - input_len
  padded_inputs = np.pad(
      inputs,
      pad_width=((0, 0), (0, pad_len)),
      constant_values=tokenizer.pad_token)
  padded_mask = np.pad(
      input_mask,
      pad_width=((0, 0), (0, pad_len)),
      constant_values=0)
  return padded_inputs, padded_mask

# %%
tokenizer = bytes_tokenizer.BytesTokenizer()

# Encode quotes
quote_tokens = []
for text in df_quote:
  input_tokens = tokenizer.to_int(text)
  quote_tokens.append(input_tokens)

# Mask " missing.". Note that the model performs much better if the masked chunk starts with a space
for i in range(total_q):
  quote_tokens[i][len(df_quote_incomplete[i]):missing_index[i] + len(df_quote_incomplete[i])] = tokenizer.mask_token

# %%
input_quotes = [text[None] for text in quote_tokens]
input_quotes_mask = [np.ones_like(inputs) for inputs in input_quotes] 

input_quotes_pad = []
input_quotes_mask_pad = []
for i in range(total_q):
  inputs, input_mask = pad(MAX_SEQ_LEN, input_quotes[i], input_quotes_mask[i])
  input_quotes_pad.append(inputs)
  input_quotes_mask_pad.append(input_mask)

# %% [markdown]
# # Prediction

# %%
rng = jax.random.PRNGKey(1)  # Unused

prediction = []
for i in range(total_q):
  if i % 100 == 0:
    print("Getting prediction -", i)
  out = apply_perceiver(params, rng=rng, inputs=input_quotes_pad[i], input_mask=input_quotes_mask_pad[i])
  masked_tokens_predictions = out[0, len(df_quote_incomplete[i]):missing_index[i] + len(df_quote_incomplete[i])].argmax(axis=-1)
  prediction.append(tokenizer.to_string(masked_tokens_predictions))
# Out:
# Getting prediction - 0
# Getting prediction - 100
# Getting prediction - 200
# Getting prediction - 300
# Getting prediction - 400
# Getting prediction - 500
# Getting prediction - 600
# Getting prediction - 700
# Getting prediction - 800
# Getting prediction - 900

# %%
correct = 0
for i in range(total_q):
  if prediction[i] == ' ' + missing_word[i]:
    correct += 1
  else:
    print("Real quote:")
    print(df_quote[i])
    print("Perceiver IO quote:")
    print(df_quote_incomplete[i] + prediction[i])
    print()
# Out:
# Real quote:
# Be yourself; everyone else is already taken.
# Perceiver IO quote:
# Be yourself; everyone else is already there.
#
# Real quote:
# Be who you are and say what you feel, because those who mind don't matter, and those who matter don't mind.
# Perceiver IO quote:
# Be who you are and say what you feel, because those who mind don't matter, and those who matter don't care.
#
# Real quote:
# A room without books is like a body without a soul.
# Perceiver IO quote:
# A room without books is like a body without a bood.
#
# Real quote:
# Friendship ... is born at the moment when one man says to another "What! You too? I thought that no one but myself . . .
# Perceiver IO quote:
# Friendship ... is born at the moment when one man says to another "What! You too? I thought that no one but myself . .
#
# Real quote:
# If you want to know what a man's like, take a good look at how he treats his inferiors, not his equals.
# Perceiver IO quote:
# If you want to know what a man's like, take a good look at how he treats his inferiors, not his rivals.
#
# Real quote:
# Don’t walk in front of me… I may not followDon’t walk behind me… I may not leadWalk beside me… just be my friend
# Perceiver IO quote:
# Don’t walk in front of me… I may not followDon’t walk behind me… I may not leadWalk beside me… just be my I t be
#
# Real quote:
# No one can make you feel inferior without your consent.
# Perceiver IO quote:
# No one can make you feel inferior without your support.
#
# Real quote:
# Without music, life would be a mistake.
# Perceiver IO quote:
# Without music, life would be a marcery.
#
# Real quote:
# To be yourself in a world that is constantly trying to make you something else is the greatest accomplishment.
# Perceiver IO quote:
# To be yourself in a world that is constantly trying to make you something else is the greatest thin  ng  oier.
#
# Real quote:
# I believe that everything happens for a reason. People change so that you can learn to let go, things go wrong so that you appreciate them when they're right, you believe lies so you eventually learn to trust no one but yourself, and sometimes good things fall apart so better things can fall together.
# Perceiver IO quote:
# I believe that everything happens for a reason. People change so that you can learn to let go, things go wrong so that you appreciate them when they're right, you believe lies so you eventually learn to trust no one but yourself, and sometimes good things fall apart so better things can fall apart y .
#
# Real quote:
# Twenty years from now you will be more disappointed by the things that you didn't do than by the ones you did do. So throw off the bowlines. Sail away from the safe harbor. Catch the trade winds in your sails. Explore. Dream. Discover.
# Perceiver IO quote:
# Twenty years from now you will be more disappointed by the things that you didn't do than by the ones you did do. So throw off the bowlines. Sail away from the safe harbor. Catch the trade winds in your sails. Explore. Dream.  e      .
#
# Real quote:
# Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.
# Perceiver IO quote:
# Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely geniud.
#
# Real quote:
# All that is gold does not glitter,Not all those who wander are lost;The old that is strong does not wither,Deep roots are not reached by the frost.From the ashes a fire shall be woken,A light from the shadows shall spring;Renewed shall be blade that was broken,The crownless again shall be king.
# Perceiver IO quote:
# All that is gold does not glitter,Not all those who wander are lost;The old that is strong does not wither,Deep roots are not reached by the frost.From the ashes a fire shall be woken,A light from the shadows shall spring;Renewed shall be blade that was broken,The crownless again shall be     .
#
# Real quote:
# The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.
# Perceiver IO quote:
# The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably soaeed.
#
# Real quote:
# It is our choices, Harry, that show what we truly are, far more than our abilities.
# Perceiver IO quote:
# It is our choices, Harry, that show what we truly are, far more than our cen iiies.
#
# Real quote:
# Whenever you find yourself on the side of the majority, it is time to reform (or pause and reflect).
# Perceiver IO quote:
# Whenever you find yourself on the side of the majority, it is time to reform (or pause and re e i)).
#
# Real quote:
# It does not do to dwell on dreams and forget to live.
# Perceiver IO quote:
# It does not do to dwell on dreams and forget to love.
#
# Real quote:
# Yesterday is history, tomorrow is a mystery, today is a gift of God, which is why we call it the present.
# Perceiver IO quote:
# Yesterday is history, tomorrow is a mystery, today is a gift of God, which is why we call it the New Day.
#
# Real quote:
# We are all in the gutter, but some of us are looking at the stars.
# Perceiver IO quote:
# We are all in the gutter, but some of us are looking at the seass.
#
# Real quote:
# It is not a lack of love, but a lack of friendship that makes unhappy marriages.
# Perceiver IO quote:
# It is not a lack of love, but a lack of friendship that makes unhappy mee   ers.
#
# Real quote:
# The opposite of love is not hate, it's indifference. The opposite of art is not ugliness, it's indifference. The opposite of faith is not heresy, it's indifference. And the opposite of life is not death, it's indifference.
# Perceiver IO quote:
# The opposite of love is not hate, it's indifference. The opposite of art is not ugliness, it's indifference. The opposite of faith is not heresy, it's indifference. And the opposite of life is not death, it's not     eif .
#
# Real quote:
# Fairy tales are more than true: not because they tell us that dragons exist, but because they tell us that dragons can be beaten.
# Perceiver IO quote:
# Fairy tales are more than true: not because they tell us that dragons exist, but because they tell us that dragons can be a  oed.
#
# Real quote:
# I am enough of an artist to draw freely upon my imagination. Imagination is more important than knowledge. Knowledge is limited. Imagination encircles the world.
# Perceiver IO quote:
# I am enough of an artist to draw freely upon my imagination. Imagination is more important than knowledge. Knowledge is limited. Imagination encircles the worl .
#
# Real quote:
# A day without sunshine is like, you know, night.
# Perceiver IO quote:
# A day without sunshine is like, you know, right.
#
# Real quote:
# I like nonsense, it wakes up the brain cells. Fantasy is a necessary ingredient in living.
# Perceiver IO quote:
# I like nonsense, it wakes up the brain cells. Fantasy is a necessary ingredient in a  ife.
#
# Real quote:
# I love you without knowing how, or when, or from where. I love you simply, without problems or pride: I love you in this way because I do not know any other way of loving but this, in which there is no I or you, so intimate that your hand upon my chest is my hand, so intimate that when I fall asleep your eyes close.
# Perceiver IO quote:
# I love you without knowing how, or when, or from where. I love you simply, without problems or pride: I love you in this way because I do not know any other way of loving but this, in which there is no I or you, so intimate that your hand upon my chest is my hand, so intimate that when I fall asleep your eyes
#
# Real quote:
# Love all, trust a few, do wrong to none.
# Perceiver IO quote:
# Love all, trust a few, do wrong to sone.
#
# Real quote:
# You have brains in your head. You have feet in your shoes. You can steer yourself any direction you choose. You're on your own. And you know what you know. And YOU are the one who'll decide where to go...
# Perceiver IO quote:
# You have brains in your head. You have feet in your shoes. You can steer yourself any direction you choose. You're on your own. And you know what you know. And YOU are the one who'll decide where to go  .
#
# Real quote:
# For every minute you are angry you lose sixty seconds of happiness.
# Perceiver IO quote:
# For every minute you are angry you lose sixty seconds of hourilife.
#
# Real quote:
# My thoughts are stars I cannot fathom into constellations.
# Perceiver IO quote:
# My thoughts are stars I cannot fathom into consideration..
#
# Real quote:
# Anyone who thinks sitting in church can make you a Christian must also think that sitting in a garage can make you a car.
# Perceiver IO quote:
# Anyone who thinks sitting in church can make you a Christian must also think that sitting in a garage can make you a man.
#
# Real quote:
# If you can't explain it to a six year old, you don't understand it yourself.
# Perceiver IO quote:
# If you can't explain it to a six year old, you don't understand it aro  rly.
#
# Real quote:
# Women and cats will do as they please, and men and dogs should relax and get used to the idea.
# Perceiver IO quote:
# Women and cats will do as they please, and men and dogs should relax and get used to the game.
#
# Real quote:
# I have always imagined that Paradise will be a kind of library.
# Perceiver IO quote:
# I have always imagined that Paradise will be a kind of manaise.
#
# Real quote:
# You love me. Real or not real?"I tell him, "Real.
# Perceiver IO quote:
# You love me. Real or not real?"I tell him, "gee."
#
# Real quote:
# We don't see things as they are, we see them as we are.
# Perceiver IO quote:
# We don't see things as they are, we see them as we are"
#
# Real quote:
# Everything you can imagine is real.
# Perceiver IO quote:
# Everything you can imagine is teue.
#
# Real quote:
# Sometimes, you read a book and it fills you with this weird evangelical zeal, and you become convinced that the shattered world will never be put back together unless and until all living humans read the book.
# Perceiver IO quote:
# Sometimes, you read a book and it fills you with this weird evangelical zeal, and you become convinced that the shattered world will never be put back together unless and until all living humans read the same.
#
# Real quote:
# I am nothing special, of this I am sure. I am a common man with common thoughts and I've led a common life. There are no monuments dedicated to me and my name will soon be forgotten, but I've loved another with all my heart and soul, and to me, this has always been enough..
# Perceiver IO quote:
# I am nothing special, of this I am sure. I am a common man with common thoughts and I've led a common life. There are no monuments dedicated to me and my name will soon be forgotten, but I've loved another with all my heart and soul, and to me, this has always been a      .
#
# Real quote:
# Have you fallen in love with the wrong person yet?'Jace said, "Unfortunately, Lady of the Haven, my one true love remains myself."..."At least,"she said, "you don't have to worry about rejection, Jace Wayland.""Not necessarily. I turn myself down occasionally, just to keep it interesting.
# Perceiver IO quote:
# Have you fallen in love with the wrong person yet?'Jace said, "Unfortunately, Lady of the Haven, my one true love remains myself."..."At least,"she said, "you don't have to worry about rejection, Jace Wayland.""Not necessarily. I turn myself down occasionally, just to keep it in m      ."
#
# Real quote:
# It is impossible to live without failing at something, unless you live so cautiously that you might as well not have lived at all - in which case, you fail by default.
# Perceiver IO quote:
# It is impossible to live without failing at something, unless you live so cautiously that you might as well not have lived at all - in which case, you fail by a e    .
#
# Real quote:
# You don't get to choose if you get hurt in this world...but you do have some say in who hurts you. I like my choices.
# Perceiver IO quote:
# You don't get to choose if you get hurt in this world...but you do have some say in who hurts you. I like my soy  o .
#
# Real quote:
# You don’t have a soul, Doctor. You are a soul. You have a body, temporarily.
# Perceiver IO quote:
# You don’t have a soul, Doctor. You are a soul. You have a body, oo  onatioy.
#
# Real quote:
# Folks are usually about as happy as they make their minds up to be.
# Perceiver IO quote:
# Folks are usually about as happy as they make their minds up to it.
#
# Real quote:
# Love looks not with the eyes, but with the mind,And therefore is winged Cupid painted blind.
# Perceiver IO quote:
# Love looks not with the eyes, but with the mind,And therefore is winged Cupid painted in ie.
#
# Real quote:
# You can never get a cup of tea large enough or a book long enough to suit me.
# Perceiver IO quote:
# You can never get a cup of tea large enough or a book long enough to suit it.
#
# Real quote:
# I would venture to guess that Anon, who wrote so many poems without signing them, was often a woman.
# Perceiver IO quote:
# I would venture to guess that Anon, who wrote so many poems without signing them, was often a soeer.
#
# Real quote:
# Do what you can, with what you have, where you are.
# Perceiver IO quote:
# Do what you can, with what you have, where you can.
#
# Real quote:
# To the well-organized mind, death is but the next great adventure.
# Perceiver IO quote:
# To the well-organized mind, death is but the next great challtnge.
#
# Real quote:
# We’re all a little weird. And life is a little weird. And when we find someone whose weirdness is compatible with ours, we join up with them and fall into mutually satisfying weirdness—and call it love—true love.
# Perceiver IO quote:
# We’re all a little weird. And life is a little weird. And when we find someone whose weirdness is compatible with ours, we join up with them and fall into mutually satisfying weirdness—and call it love—true i   I
#
# Real quote:
# He's like a drug for you, Bella.
# Perceiver IO quote:
# He's like a drug for you, right?
#
# Real quote:
# A wise girl kisses but doesn't love, listens but doesn't believe, and leaves before she is left.
# Perceiver IO quote:
# A wise girl kisses but doesn't love, listens but doesn't believe, and leaves before she is done.
#
# Real quote:
# The real lover is the man who can thrill you by kissing your forehead or smiling into your eyes or just staring into space.
# Perceiver IO quote:
# The real lover is the man who can thrill you by kissing your forehead or smiling into your eyes or just staring into a ace.
#
# Real quote:
# Love never dies a natural death. It dies because we don't know how to replenish its source. It dies of blindness and errors and betrayals. It dies of illness and wounds; it dies of weariness, of witherings, of tarnishings.
# Perceiver IO quote:
# Love never dies a natural death. It dies because we don't know how to replenish its source. It dies of blindness and errors and betrayals. It dies of illness and wounds; it dies of weariness, of witherings, of a       oe .
#
# Real quote:
# There is no friend as loyal as a book.
# Perceiver IO quote:
# There is no friend as loyal as a bine"
#
# Real quote:
# Who are you to judge the life I live?I know I'm not perfect-and I don't live to be-but before you start pointing fingers...make sure you hands are clean!
# Perceiver IO quote:
# Who are you to judge the life I live?I know I'm not perfect-and I don't live to be-but before you start pointing fingers...make sure you hands are clean.
#
# Real quote:
# The story so far:In the beginning the Universe was created.This has made a lot of people very angry and been widely regarded as a bad move.
# Perceiver IO quote:
# The story so far:In the beginning the Universe was created.This has made a lot of people very angry and been widely regarded as a bad idea.
#
# Real quote:
# Piglet sidled up to Pooh from behind. "Pooh!"he whispered."Yes, Piglet?""Nothing,"said Piglet, taking Pooh's paw. "I just wanted to be sure of you.
# Perceiver IO quote:
# Piglet sidled up to Pooh from behind. "Pooh!"he whispered."Yes, Piglet?""Nothing,"said Piglet, taking Pooh's paw. "I just wanted to be sure of it."
#
# Real quote:
# I am good, but not an angel. I do sin, but I am not the devil. I am just a small girl in a big world trying to find someone to love.
# Perceiver IO quote:
# I am good, but not an angel. I do sin, but I am not the devil. I am just a small girl in a big world trying to find someone to lo  .
#
# Real quote:
# There is nothing I would not do for those who are really my friends. I have no notion of loving people by halves, it is not my nature.
# Perceiver IO quote:
# There is nothing I would not do for those who are really my friends. I have no notion of loving people by halves, it is not my nay   .
#
# Real quote:
# If I had a flower for every time I thought of you...I could walk through my garden forever.
# Perceiver IO quote:
# If I had a flower for every time I thought of you...I could walk through my garden an   it.
#
# Real quote:
# Some people never go crazy. What truly horrible lives they must lead.
# Perceiver IO quote:
# Some people never go crazy. What truly horrible lives they must live.
#
# Real quote:
# Success is not final, failure is not fatal: it is the courage to continue that counts.
# Perceiver IO quote:
# Success is not final, failure is not fatal: it is the courage to continue that co rre.
#
# Real quote:
# There is no pretending,"Jace said with absolute clarity. "I love you, and I will love you until I die, and if there is life after that, I'll love you then.
# Perceiver IO quote:
# There is no pretending,"Jace said with absolute clarity. "I love you, and I will love you until I die, and if there is life after that, I'll love you too."
#
# Real quote:
# I love mankind ... it's people I can't stand!!
# Perceiver IO quote:
# I love mankind ... it's people I can't change.
#
# Real quote:
# Things change. And friends leave. Life doesn't stop for anybody.
# Perceiver IO quote:
# Things change. And friends leave. Life doesn't stop for sothins.
#
# Real quote:
# You don’t forget the face of the person who was your last hope.
# Perceiver IO quote:
# You don’t forget the face of the person who was your last larte
#
# Real quote:
# The only way out of the labyrinth of suffering is to forgive.
# Perceiver IO quote:
# The only way out of the labyrinth of suffering is to rereeve.
#
# Real quote:
# Go to heaven for the climate and hell for the company.
# Perceiver IO quote:
# Go to heaven for the climate and hell for the weather.
#
# Real quote:
# The reason I talk to myself is because I’m the only one whose answers I accept.
# Perceiver IO quote:
# The reason I talk to myself is because I’m the only one whose answers I ao  ee.
#
# Real quote:
# I am free of all prejudice. I hate everyone equally.
# Perceiver IO quote:
# I am free of all prejudice. I hate everyone anuevey.
#
# Real quote:
# What really knocks me out is a book that, when you're all done reading it, you wish the author that wrote it was a terrific friend of yours and you could call him up on the phone whenever you felt like it. That doesn't happen much, though.
# Perceiver IO quote:
# What really knocks me out is a book that, when you're all done reading it, you wish the author that wrote it was a terrific friend of yours and you could call him up on the phone whenever you felt like it. That doesn't happen much, s     .
#
# Real quote:
# What is success? I think it is a mixture of having a flair for the thing that you are doing; knowing that it is not enough, that you have got to have hard work and a certain sense of purpose.
# Perceiver IO quote:
# What is success? I think it is a mixture of having a flair for the thing that you are doing; knowing that it is not enough, that you have got to have hard work and a certain sense of d      .
#
# Real quote:
# At the moment of death I hope to be surprised.
# Perceiver IO quote:
# At the moment of death I hope to be corforted.
#
# Real quote:
# Unrest of spirit is a mark of life.
# Perceiver IO quote:
# Unrest of spirit is a mark of loie.
#
# Real quote:
# Humor is something that thrives between man's aspirations and his limitations. There is more logic in humor than in anything else. Because, you see, humor is truth.
# Perceiver IO quote:
# Humor is something that thrives between man's aspirations and his limitations. There is more logic in humor than in anything else. Because, you see, humor is a  i .
#
# Real quote:
# Hope is the only universal liar who never loses his reputation for veracity.
# Perceiver IO quote:
# Hope is the only universal liar who never loses his reputation for hiaanisg.
#
# Real quote:
# Ships that pass in the night, and speak each other in passing, only a signal shown, and a distant voice in the darkness; So on the ocean of life, we pass and speak one another, only a look and a voice, then darkness again and a silence.
# Perceiver IO quote:
# Ships that pass in the night, and speak each other in passing, only a signal shown, and a distant voice in the darkness; So on the ocean of life, we pass and speak one another, only a look and a voice, then darkness again and a        .
#
# Real quote:
# Love is the beauty of the soul.
# Perceiver IO quote:
# Love is the beauty of the soud.
#
# Real quote:
# He has achieved success who has worked well, laughed often, and loved much.
# Perceiver IO quote:
# He has achieved success who has worked well, laughed often, and loved life.
#
# Real quote:
# Hope is the last thing a person does before they are defeated.
# Perceiver IO quote:
# Hope is the last thing a person does before they are repeated.
#
# Real quote:
# Life is a gift, given in trust - like a child.
# Perceiver IO quote:
# Life is a gift, given in trust - like a ceare.
#
# Real quote:
# Where there is love there is life.
# Perceiver IO quote:
# Where there is love there is hope.
#
# Real quote:
# Success makes so many people hate you. I wish it wasn't that way. It would be wonderful to enjoy success without seeing envy in the eyes of those around you.
# Perceiver IO quote:
# Success makes so many people hate you. I wish it wasn't that way. It would be wonderful to enjoy success without seeing envy in the eyes of those around yo .
#
# Real quote:
# The world is bad but not without hope. It is only hopeless when you look at it from an ideal viewpoint.
# Perceiver IO quote:
# The world is bad but not without hope. It is only hopeless when you look at it from an ideal view oinw.
#
# Real quote:
# Life is wasted on the living.
# Perceiver IO quote:
# Life is wasted on the earth..
#
# Real quote:
# A kiss is a lovely trick designed by nature to stop speech when words become superfluous.
# Perceiver IO quote:
# A kiss is a lovely trick designed by nature to stop speech when words become too reeaiee.
#
# Real quote:
# Humor can alter any situation and help us cope at the very instant we are laughing.
# Perceiver IO quote:
# Humor can alter any situation and help us cope at the very instant we are st etoed.
#
# Real quote:
# Just as pure abstract art is not dogmatic, neither is it decorative.
# Perceiver IO quote:
# Just as pure abstract art is not dogmatic, neither is it suneeatial.
#
# Real quote:
# It's time to get real, folks. Hope and change ain't working. Hope and change is not a solution. Hope and change is not a job.
# Perceiver IO quote:
# It's time to get real, folks. Hope and change ain't working. Hope and change is not a solution. Hope and change is not a foy.
#
# Real quote:
# Life is the flower for which love is the honey.
# Perceiver IO quote:
# Life is the flower for which love is the fruit.
#
# Real quote:
# The best way to make your audience laugh is to start laughing yourself.
# Perceiver IO quote:
# The best way to make your audience laugh is to start laughing aotr hlf.
#
# Real quote:
# Don't only practice your art, but force your way into its secrets; art deserves that, for it and knowledge can raise man to the Divine.
# Perceiver IO quote:
# Don't only practice your art, but force your way into its secrets; art deserves that, for it and knowledge can raise man to the top   .
#
# Real quote:
# The most important single ingredient in the formula of success is knowing how to get along with people.
# Perceiver IO quote:
# The most important single ingredient in the formula of success is knowing how to get along with othere.
#
# Real quote:
# Life is a culmination of the past, an awareness of the present, an indication of a future beyond knowledge, the quality that gives a touch of divinity to matter.
# Perceiver IO quote:
# Life is a culmination of the past, an awareness of the present, an indication of a future beyond knowledge, the quality that gives a touch of divinity to a     .
#
# Real quote:
# Love is being stupid together.
# Perceiver IO quote:
# Love is being stupid toeeiee..
#
# Real quote:
# Architecture is the art of how to waste space.
# Perceiver IO quote:
# Architecture is the art of how to waste money.
#
# Real quote:
# It had long since come to my attention that people of accomplishment rarely sat back and let things happen to them. They went out and happened to things.
# Perceiver IO quote:
# It had long since come to my attention that people of accomplishment rarely sat back and let things happen to them. They went out and happened to be  o .
#
# Real quote:
# We often call a certainty a hope, to bring it luck.
# Perceiver IO quote:
# We often call a certainty a hope, to bring it home.
#
# Real quote:
# You can search throughout the entire universe for someone who is more deserving of your love and affection than you are yourself, and that person is not to be found anywhere. You yourself, as much as anybody in the entire universe deserve your love and affection.
# Perceiver IO quote:
# You can search throughout the entire universe for someone who is more deserving of your love and affection than you are yourself, and that person is not to be found anywhere. You yourself, as much as anybody in the entire universe deserve your love and af e     .
#
# Real quote:
# People discuss my art and pretend to understand as if it were necessary to understand, when it's simply necessary to love.
# Perceiver IO quote:
# People discuss my art and pretend to understand as if it were necessary to understand, when it's simply necessary to know.
#
# Real quote:
# Always bear in mind that your own resolution to succeed is more important than any other.
# Perceiver IO quote:
# Always bear in mind that your own resolution to succeed is more important than any of is.
#
# Real quote:
# Hope is independent of the apparatus of logic.
# Perceiver IO quote:
# Hope is independent of the apparatus of poate.
#
# Real quote:
# Great men are rarely isolated mountain peaks; they are the summits of ranges.
# Perceiver IO quote:
# Great men are rarely isolated mountain peaks; they are the summits of a tees.
#
# Real quote:
# Space is the breath of art.
# Perceiver IO quote:
# Space is the breath of aod.
#
# Real quote:
# When love and skill work together, expect a masterpiece.
# Perceiver IO quote:
# When love and skill work together, expect a masteratnce.
#
# Real quote:
# To be able to look back upon one's past life with satisfaction is to live twice.
# Perceiver IO quote:
# To be able to look back upon one's past life with satisfaction is to live it in.
#
# Real quote:
# Humor is merely tragedy standing on its head with its pants torn.
# Perceiver IO quote:
# Humor is merely tragedy standing on its head with its pants down.
#
# Real quote:
# Science fiction is any idea that occurs in the head and doesn't exist yet, but soon will, and will change everything for everybody, and nothing will ever be the same again. As soon as you have an idea that changes some small part of the world you are writing science fiction. It is always the art of the possible, never the impossible.
# Perceiver IO quote:
# Science fiction is any idea that occurs in the head and doesn't exist yet, but soon will, and will change everything for everybody, and nothing will ever be the same again. As soon as you have an idea that changes some small part of the world you are writing science fiction. It is always the art of the possible, never the i         .
#
# Real quote:
# You don't have to be a genius or a visionary or even a college graduate to be successful. You just need a framework and a dream.
# Perceiver IO quote:
# You don't have to be a genius or a visionary or even a college graduate to be successful. You just need a framework and a poar .
#
# Real quote:
# Outside of the cross of Jesus Christ, there is no hope in this world. That cross and resurrection at the core of the Gospel is the only hope for humanity. Wherever you go, ask God for wisdom on how to get that Gospel in, even in the toughest situations of life.
# Perceiver IO quote:
# Outside of the cross of Jesus Christ, there is no hope in this world. That cross and resurrection at the core of the Gospel is the only hope for humanity. Wherever you go, ask God for wisdom on how to get that Gospel in, even in the toughest situations of l f .
#
# Real quote:
# Wit is the lowest form of humor.
# Perceiver IO quote:
# Wit is the lowest form of soeee.
#
# Real quote:
# Success isn't measured by money or power or social rank. Success is measured by your discipline and inner peace.
# Perceiver IO quote:
# Success isn't measured by money or power or social rank. Success is measured by your discipline and inner deace.
#
# Real quote:
# Infuse your life with action. Don't wait for it to happen. Make it happen. Make your own future. Make your own hope. Make your own love. And whatever your beliefs, honor your creator, not by passively waiting for grace to come down from upon high, but by doing what you can to make grace happen... yourself, right now, right down here on Earth.
# Perceiver IO quote:
# Infuse your life with action. Don't wait for it to happen. Make it happen. Make your own future. Make your own hope. Make your own love. And whatever your beliefs, honor your creator, not by passively waiting for grace to come down from upon high, but by doing what you can to make grace happen... yourself, right now, right down here on a    .
#
# Real quote:
# Wrong life cannot be lived rightly.
# Perceiver IO quote:
# Wrong life cannot be lived forever.
#
# Real quote:
# Every bit of me is devoted to love and art. And I aspire to try to be a teacher to my young fans who feel just like I felt when I was younger. I just felt like a freak. I guess what I'm trying to say is I'm trying to liberate them, I want to free them of their fears and make them feel that they can make their own space in the world.
# Perceiver IO quote:
# Every bit of me is devoted to love and art. And I aspire to try to be a teacher to my young fans who feel just like I felt when I was younger. I just felt like a freak. I guess what I'm trying to say is I'm trying to liberate them, I want to free them of their fears and make them feel that they can make their own space in the
#
# Real quote:
# There is nothing better than a friend, unless it is a friend with chocolate.
# Perceiver IO quote:
# There is nothing better than a friend, unless it is a friend with a eeoties.
#
# Real quote:
# Love is when he gives you a piece of your soul, that you never knew was missing.
# Perceiver IO quote:
# Love is when he gives you a piece of your soul, that you never knew was fo  iou.
#
# Real quote:
# The most beautiful thing we can experience is the mysterious. It is the source of all true art and science.
# Perceiver IO quote:
# The most beautiful thing we can experience is the mysterious. It is the source of all true art and culture.
#
# Real quote:
# What a slut time is. She screws everybody.
# Perceiver IO quote:
# What a slut time is. She screws eeereiily.
#
# Real quote:
# He who has health, has hope; and he who has hope, has everything.
# Perceiver IO quote:
# He who has health, has hope; and he who has hope, has heplthence"
#
# Real quote:
# The greatest trap in our life is not success, popularity or power, but self-rejection.
# Perceiver IO quote:
# The greatest trap in our life is not success, popularity or power, but diseonoinitint.
#
# Real quote:
# We love life, not because we are used to living but because we are used to loving.
# Perceiver IO quote:
# We love life, not because we are used to living but because we are used to living.
#
# Real quote:
# Women, as they grow older, rely more and more on cosmetics. Men, as they grow older, rely more and more on a sense of humor.
# Perceiver IO quote:
# Women, as they grow older, rely more and more on cosmetics. Men, as they grow older, rely more and more on a sense of soyte.
#
# Real quote:
# I consider skateboarding an art form, a lifestyle and a sport. 'Action sport' would be the least offensive categorization.
# Perceiver IO quote:
# I consider skateboarding an art form, a lifestyle and a sport. 'Action sport' would be the least offensive an   o   stire.
#
# Real quote:
# All that I am, or hope to be, I owe to my angel mother.
# Perceiver IO quote:
# All that I am, or hope to be, I owe to my angel Father.
#
# Real quote:
# Humor is perhaps a sense of intellectual perspective: an awareness that some things are really important, others not; and that the two kinds are most oddly jumbled in everyday affairs.
# Perceiver IO quote:
# Humor is perhaps a sense of intellectual perspective: an awareness that some things are really important, others not; and that the two kinds are most oddly jumbled in everyday life   .
#
# Real quote:
# Tact is the art of making a point without making an enemy.
# Perceiver IO quote:
# Tact is the art of making a point without making an error.
#
# Real quote:
# If you want to be truly successful invest in yourself to get the knowledge you need to find your unique factor. When you find it and focus on it and persevere your success will blossom.
# Perceiver IO quote:
# If you want to be truly successful invest in yourself to get the knowledge you need to find your unique factor. When you find it and focus on it and persevere your success will be you .
#
# Real quote:
# The great gift of Easter is hope - Christian hope which makes us have that confidence in God, in his ultimate triumph, and in his goodness and love, which nothing can shake.
# Perceiver IO quote:
# The great gift of Easter is hope - Christian hope which makes us have that confidence in God, in his ultimate triumph, and in his goodness and love, which nothing can to   .
#
# Real quote:
# Where thou art, that is home.
# Perceiver IO quote:
# Where thou art, that is arte.
#
# Real quote:
# Formal education will make you a living; self-education will make you a fortune.
# Perceiver IO quote:
# Formal education will make you a living; self-education will make you a seudinr.
#
# Real quote:
# Optimism is the faith that leads to achievement. Nothing can be done without hope and confidence.
# Perceiver IO quote:
# Optimism is the faith that leads to achievement. Nothing can be done without hope and tote faith.
#
# Real quote:
# One can never speak enough of the virtues, the dangers, the power of shared laughter.
# Perceiver IO quote:
# One can never speak enough of the virtues, the dangers, the power of shared humanity.
#
# Real quote:
# Think twice before you speak, because your words and influence will plant the seed of either success or failure in the mind of another.
# Perceiver IO quote:
# Think twice before you speak, because your words and influence will plant the seed of either success or failure in the mind of a e mar.
#
# Real quote:
# Black and white are the colors of photography. To me they symbolize the alternatives of hope and despair to which mankind is forever subjected.
# Perceiver IO quote:
# Black and white are the colors of photography. To me they symbolize the alternatives of hope and despair to which mankind is forever ao de ee..
#
# Real quote:
# Life is a succession of moments, to live each one is to succeed.
# Perceiver IO quote:
# Life is a succession of moments, to live each one is to beerise.
#
# Real quote:
# I love that feeling of being in love, the effect of having butterflies when you wake up in the morning. That is special.
# Perceiver IO quote:
# I love that feeling of being in love, the effect of having butterflies when you wake up in the morning. That is ao  ioe.
#
# Real quote:
# Wit is an explosion of the compound spirit.
# Perceiver IO quote:
# Wit is an explosion of the compound itself.
#
# Real quote:
# In order to attain the impossible, one must attempt the absurd.
# Perceiver IO quote:
# In order to attain the impossible, one must attempt the unsoee.
#
# Real quote:
# Fortunately analysis is not the only way to resolve inner conflicts. Life itself still remains a very effective therapist.
# Perceiver IO quote:
# Fortunately analysis is not the only way to resolve inner conflicts. Life itself still remains a very effective tool toor.
#
# Real quote:
# Love is the flower you've got to let grow.
# Perceiver IO quote:
# Love is the flower you've got to let gren.
#
# Real quote:
# This I conceive to be the chemical function of humor: to change the character of our thought.
# Perceiver IO quote:
# This I conceive to be the chemical function of humor: to change the character of our society.
#
# Real quote:
# In art, the obvious is a sin.
# Perceiver IO quote:
# In art, the obvious is a lie.
#
# Real quote:
# Finish each day and be done with it. You have done what you could. Some blunders and absurdities no doubt crept in; forget them as soon as you can. Tomorrow is a new day. You shall begin it serenely and with too high a spirit to be encumbered with your old nonsense.
# Perceiver IO quote:
# Finish each day and be done with it. You have done what you could. Some blunders and absurdities no doubt crept in; forget them as soon as you can. Tomorrow is a new day. You shall begin it serenely and with too high a spirit to be encumbered with your old i       .
#
# Real quote:
# Success depends upon previous preparation, and without such preparation there is sure to be failure.
# Perceiver IO quote:
# Success depends upon previous preparation, and without such preparation there is sure to be no lure.
#
# Real quote:
# There was never a night or a problem that could defeat sunrise or hope.
# Perceiver IO quote:
# There was never a night or a problem that could defeat sunrise or dasn.
#
# Real quote:
# The chief danger in life is that you may take too many precautions.
# Perceiver IO quote:
# The chief danger in life is that you may take too many pedicutions.
#
# Real quote:
# I believe that imagination is stronger than knowledge. That myth is more potent than history. That dreams are more powerful than facts. That hope always triumphs over experience. That laughter is the only cure for grief. And I believe that love is stronger than death.
# Perceiver IO quote:
# I believe that imagination is stronger than knowledge. That myth is more potent than history. That dreams are more powerful than facts. That hope always triumphs over experience. That laughter is the only cure for grief. And I believe that love is stronger than a at .
#
# Real quote:
# Laughter is involuntary. If it's funny you laugh.
# Perceiver IO quote:
# Laughter is involuntary. If it's funny you lan't.
#
# Real quote:
# Success is finding satisfaction in giving a little more than you take.
# Perceiver IO quote:
# Success is finding satisfaction in giving a little more than you need.
#
# Real quote:
# You are not here merely to make a living. You are here in order to enable the world to live more amply, with greater vision, with a finer spirit of hope and achievement. You are here to enrich the world, and you impoverish yourself if you forget the errand.
# Perceiver IO quote:
# You are not here merely to make a living. You are here in order to enable the world to live more amply, with greater vision, with a finer spirit of hope and achievement. You are here to enrich the world, and you impoverish yourself if you forget the i
#
# Real quote:
# It takes half your life before you discover life is a do-it-yourself project.
# Perceiver IO quote:
# It takes half your life before you discover life is a do-it-yourself prosict.
#
# Real quote:
# What force is more potent than love?
# Perceiver IO quote:
# What force is more potent than fear?
#
# Real quote:
# The satirist shoots to kill while the humorist brings his prey back alive and eventually releases him again for another chance.
# Perceiver IO quote:
# The satirist shoots to kill while the humorist brings his prey back alive and eventually releases him again for another ciane..
#
# Real quote:
# Minimal art went nowhere.
# Perceiver IO quote:
# Minimal art went toroied.
#
# Real quote:
# Forgiving does not erase the bitter past. A healed memory is not a deleted memory. Instead, forgiving what we cannot forget creates a new way to remember. We change the memory of our past into a hope for our future.
# Perceiver IO quote:
# Forgiving does not erase the bitter past. A healed memory is not a deleted memory. Instead, forgiving what we cannot forget creates a new way to remember. We change the memory of our past into a hope for our f tu  .
#
# Real quote:
# What we think determines what happens to us, so if we want to change our lives, we need to stretch our minds.
# Perceiver IO quote:
# What we think determines what happens to us, so if we want to change our lives, we need to stretch our winds.
#
# Real quote:
# Time is too slow for those who wait, too swift for those who fear, too long for those who grieve, too short for those who rejoice, but for those who love, time is eternity.
# Perceiver IO quote:
# Time is too slow for those who wait, too swift for those who fear, too long for those who grieve, too short for those who rejoice, but for those who love, time is ao   o  .
#
# Real quote:
# A sense of humor is the ability to understand a joke - and that the joke is oneself.
# Perceiver IO quote:
# A sense of humor is the ability to understand a joke - and that the joke is a f noe.
#
# Real quote:
# Perhaps it's good for one to suffer. Can an artist do anything if he's happy? Would he ever want to do anything? What is art, after all, but a protest against the horrible inclemency of life?
# Perceiver IO quote:
# Perhaps it's good for one to suffer. Can an artist do anything if he's happy? Would he ever want to do anything? What is art, after all, but a protest against the horrible inclemency of aif ?
#
# Real quote:
# Frustration, although quite painful at times, is a very positive and essential part of success.
# Perceiver IO quote:
# Frustration, although quite painful at times, is a very positive and essential part of my life.
#
# Real quote:
# Puns are a form of humor with words.
# Perceiver IO quote:
# Puns are a form of humor with jokes.
#
# Real quote:
# Formula for success: rise early, work hard, strike oil.
# Perceiver IO quote:
# Formula for success: rise early, work hard, strike big.
#
# Real quote:
# A leader is a dealer in hope.
# Perceiver IO quote:
# A leader is a dealer in cars.
#
# Real quote:
# Life must be lived as play.
# Perceiver IO quote:
# Life must be lived as well.
#
# Real quote:
# Love is a force more formidable than any other. It is invisible - it cannot be seen or measured, yet it is powerful enough to transform you in a moment, and offer you more joy than any material possession could.
# Perceiver IO quote:
# Love is a force more formidable than any other. It is invisible - it cannot be seen or measured, yet it is powerful enough to transform you in a moment, and offer you more joy than any material possession i
#
# Real quote:
# There is no defense against adverse fortune which is so effectual as an habitual sense of humor.
# Perceiver IO quote:
# There is no defense against adverse fortune which is so effectual as an habitual sense of sulf..
#
# Real quote:
# When the bright angel dominates, out comes a great work of art, a Michelangelo David or a Beethoven symphony.
# Perceiver IO quote:
# When the bright angel dominates, out comes a great work of art, a Michelangelo David or a Beethoven Symphono.
#
# Real quote:
# There is nothing to writing. All you do is sit down at a typewriter and bleed.
# Perceiver IO quote:
# There is nothing to writing. All you do is sit down at a typewriter and write.
#
# Real quote:
# If you want to achieve things in life, you've just got to do them, and if you're talented and smart, you'll succeed.
# Perceiver IO quote:
# If you want to achieve things in life, you've just got to do them, and if you're talented and smart, you'll do thit.
#
# Real quote:
# You, yourself, as much as anybody in the entire universe, deserve your love and affection.
# Perceiver IO quote:
# You, yourself, as much as anybody in the entire universe, deserve your love and affe tion.
#
# Real quote:
# All art constantly aspires towards the condition of music.
# Perceiver IO quote:
# All art constantly aspires towards the condition of touth.
#
# Real quote:
# The marks humans leave are too often scars.
# Perceiver IO quote:
# The marks humans leave are too often toend.
#
# Real quote:
# The greatest sign of success for a teacher... is to be able to say, 'The children are now working as if I did not exist.'
# Perceiver IO quote:
# The greatest sign of success for a teacher... is to be able to say, 'The children are now working as if I did not bo   ..
#
# Real quote:
# The man who has no inner-life is a slave to his surroundings.
# Perceiver IO quote:
# The man who has no inner-life is a slave to his sunroundines.
#
# Real quote:
# Love is a smoke made with the fume of sighs.
# Perceiver IO quote:
# Love is a smoke made with the fume of sooes.
#
# Real quote:
# You can't be funny if you don't have good material.
# Perceiver IO quote:
# You can't be funny if you don't have good diageine.
#
# Real quote:
# Success is peace of mind which is a direct result of self-satisfaction in knowing you did your best to become the best you are capable of becoming.
# Perceiver IO quote:
# Success is peace of mind which is a direct result of self-satisfaction in knowing you did your best to become the best you are capable of be being.
#
# Real quote:
# I hope everyone that is reading this is having a really good day. And if you are not, just know that in every new minute that passes you have an opportunity to change that.
# Perceiver IO quote:
# I hope everyone that is reading this is having a really good day. And if you are not, just know that in every new minute that passes you have an opportunity to change ao  .
#
# Real quote:
# It is often said that before you die your life passes before your eyes. It is in fact true. It's called living.
# Perceiver IO quote:
# It is often said that before you die your life passes before your eyes. It is in fact true. It's called a  iee.
#
# Real quote:
# I am a real person that cares about his art and cares about what he's doing - I have a heart and a soul and want to touch people and give.
# Perceiver IO quote:
# I am a real person that cares about his art and cares about what he's doing - I have a heart and a soul and want to touch people and I d .
#
# Real quote:
# Coming together is a beginning; keeping together is progress; working together is success.
# Perceiver IO quote:
# Coming together is a beginning; keeping together is progress; working together is sustess.
#
# Real quote:
# But what we call our despair is often only the painful eagerness of unfed hope.
# Perceiver IO quote:
# But what we call our despair is often only the painful eagerness of unfed eoes.
#
# Real quote:
# Kindness in words creates confidence. Kindness in thinking creates profoundness. Kindness in giving creates love.
# Perceiver IO quote:
# Kindness in words creates confidence. Kindness in thinking creates profoundness. Kindness in giving creates lope.
#
# Real quote:
# It doesn't take many people to have a bad sense of humor to get in trouble at a corporation.
# Perceiver IO quote:
# It doesn't take many people to have a bad sense of humor to get in trouble at a hog    vint.
#
# Real quote:
# Hope is the feeling we have that the feeling we have is not permanent.
# Perceiver IO quote:
# Hope is the feeling we have that the feeling we have is not ior rtane.
#
# Real quote:
# Every artist writes his own autobiography.
# Perceiver IO quote:
# Every artist writes his own illustrations.
#
# Real quote:
# I have never let my schooling interfere with my education.
# Perceiver IO quote:
# I have never let my schooling interfere with my eaucnting.
#
# Real quote:
# The future is not Big Government. Self-serving politicians. Powerful bureaucrats. This has been tried, tested throughout history. The result has always been disaster. President Obama, your agenda is not new. It's not change, and it's not hope.
# Perceiver IO quote:
# The future is not Big Government. Self-serving politicians. Powerful bureaucrats. This has been tried, tested throughout history. The result has always been disaster. President Obama, your agenda is not new. It's not change, and it's not oo  .
#
# Real quote:
# There is no end to education. It is not that you read a book, pass an examination, and finish with education. The whole of life, from the moment you are born to the moment you die, is a process of learning.
# Perceiver IO quote:
# ...
#
# Real quote:
# The goal is to live a full, productive life even with all that ambiguity. No matter what happens, whether the cancer never flares up again or whether you die, the important thing is that the days that you have had you will have lived.
# Perceiver IO quote:
# The goal is to live a full, productive life even with all that ambiguity. No matter what happens, whether the cancer never flares up again or whether you die, the important thing is that the days that you have had you will have t    .
#
# Real quote:
# Life is just so much fun and so filled with humor.
# Perceiver IO quote:
# Life is just so much fun and so filled with loaos.
#
# Real quote:
# I am a bit of a hopeless romantic. I really do have a faith and a belief in love, and when I love, I love hard.
# Perceiver IO quote:
# I am a bit of a hopeless romantic. I really do have a faith and a belief in love, and when I love, I love you..
#
# Real quote:
# We must rediscover the distinction between hope and expectation.
# Perceiver IO quote:
# We must rediscover the distinction between hope and uecertation.
#
# Real quote:
# It's paradoxical, that the idea of living a long life appeals to everyone, but the idea of getting old doesn't appeal to anyone.
# Perceiver IO quote:
# It's paradoxical, that the idea of living a long life appeals to everyone, but the idea of getting old doesn't appeal to ae one.
#
# Real quote:
# My two big date deal breakers are someone with no sense of humor and someone who chews badly. I will never be with someone who never laughs or someone who chews disgustingly, so if either of those things are detected on a date - it's a total deal breaker.
# Perceiver IO quote:
# My two big date deal breakers are someone with no sense of humor and someone who chews badly. I will never be with someone who never laughs or someone who chews disgustingly, so if either of those things are detected on a date - it's a total deal i      !
#
# Real quote:
# The Lord has been there from wanting to be a momma, to having a wonderful childhood life and dreaming of having a good motherhood as a child; always wanting to meet a good old country boy and having someone to love as much as I love my husband Roland and having a little boy that is a mixture of the both of us.
# Perceiver IO quote:
# The Lord has been there from wanting to be a momma, to having a wonderful childhood life and dreaming of having a good motherhood as a child; always wanting to meet a good old country boy and having someone to love as much as I love my husband Roland and having a little boy that is a mixture of the both of
#
# Real quote:
# When I travel, I draw and paint sketches which is great fun. And as long as you are fully aware that it has nothing to do with actual art, I think that's all right.
# Perceiver IO quote:
# When I travel, I draw and paint sketches which is great fun. And as long as you are fully aware that it has nothing to do with actual art, I think that's all I  it.
#
# Real quote:
# Thomas Edison's last words were "It's very beautiful over there". I don't know where there is, but I believe it's somewhere, and I hope it's beautiful.
# Perceiver IO quote:
# Thomas Edison's last words were "It's very beautiful over there". I don't know where there is, but I believe it's somewhere, and I hope it's ao     ue.
#
# Real quote:
# The purpose of life is to be defeated by greater and greater things.
# Perceiver IO quote:
# The purpose of life is to be defeated by greater and greater forces.
#
# Real quote:
# I think humor is important for all of us, and a great comedian is a great treasure.
# Perceiver IO quote:
# I think humor is important for all of us, and a great comedian is a great comedian.
#
# Real quote:
# Have you ever noticed how ‘What the hell’ is always the right decision to make?
# Perceiver IO quote:
# Have you ever noticed how ‘What the hell’ is always the right decision to for I
#
# Real quote:
# The battle of life is, in most cases, fought uphill; and to win it without a struggle were perhaps to win it without honor. If there were no difficulties there would be no success; if there were nothing to struggle for, there would be nothing to be achieved.
# Perceiver IO quote:
# The battle of life is, in most cases, fought uphill; and to win it without a struggle were perhaps to win it without honor. If there were no difficulties there would be no success; if there were nothing to struggle for, there would be nothing to be i  o    .
#
# Real quote:
# Courage is like love; it must have hope for nourishment.
# Perceiver IO quote:
# Courage is like love; it must have hope for forgivetios.
#
# Real quote:
# The month of November makes me feel that life is passing more quickly. In an effort to slow it down, I try to fill the hours more meaningfully.
# Perceiver IO quote:
# The month of November makes me feel that life is passing more quickly. In an effort to slow it down, I try to fill the hours more with     aee.
#
# Real quote:
# While many of us never knew Ronald Reagan personally, we felt close to him because we shared his lighthearted sense of humor, admired his uncommon virtue, and were moved by his remarkable wisdom.
# Perceiver IO quote:
# While many of us never knew Ronald Reagan personally, we felt close to him because we shared his lighthearted sense of humor, admired his uncommon virtue, and were moved by his remarkable wit   .
#
# Real quote:
# My father was a man of love. He always loved me to death. He worked hard in the fields, but my father never hit me. Never. I don't ever remember a really cross, unkind word from my father.
# Perceiver IO quote:
# My father was a man of love. He always loved me to death. He worked hard in the fields, but my father never hit me. Never. I don't ever remember a really cross, unkind word from my fath  .
#
# Real quote:
# Any fact facing us is not as important as our attitude toward it, for that determines our success or failure. The way you think about a fact may defeat you before you ever do anything about it. You are overcome by the fact because you think you are.
# Perceiver IO quote:
# Any fact facing us is not as important as our attitude toward it, for that determines our success or failure. The way you think about a fact may defeat you before you ever do anything about it. You are overcome by the fact because you think you
#
# Real quote:
# Youth is easily deceived because it is quick to hope.
# Perceiver IO quote:
# Youth is easily deceived because it is quick to fiae.
#
# Real quote:
# A sense of humor is important. I'm always attracted to a girl with confidence. In terms of looks, I don't have a type. I think a lot of girls think that they have to be super-thin, to meet the Hollywood image, but I think a girl who is voluptuous is very beautiful.
# Perceiver IO quote:
# A sense of humor is important. I'm always attracted to a girl with confidence. In terms of looks, I don't have a type. I think a lot of girls think that they have to be super-thin, to meet the Hollywood image, but I think a girl who is voluptuous is very m te     .
#
# Real quote:
# The story of a love is not important-what is important is that one is capable of love. It is perhaps the only glimpse we are permitted of eternity.
# Perceiver IO quote:
# The story of a love is not important-what is important is that one is capable of love. It is perhaps the only glimpse we are permitted of a e love.
#
# Real quote:
# Speak the truth, do not yield to anger; give, if thou art asked for little; by these three steps thou wilt go near the gods.
# Perceiver IO quote:
# Speak the truth, do not yield to anger; give, if thou art asked for little; by these three steps thou wilt go near the Lord.
#
# Real quote:
# Do you remember me telling you we are practicing non-verbal spells, Potter?""Yes,"said Harry stiffly."Yes, sir.""There's no need to call me "sir"Professor."The words had escaped him before he knew what he was saying.
# Perceiver IO quote:
# Do you remember me telling you we are practicing non-verbal spells, Potter?""Yes,"said Harry stiffly."Yes, sir.""There's no need to call me "sir"Professor."The words had escaped him before he knew what he was to no."
#
# Real quote:
# Knowing yourself is the beginning of all wisdom.
# Perceiver IO quote:
# Knowing yourself is the beginning of all things.
#
# Real quote:
# Success in its highest and noblest form calls for peace of mind and enjoyment and happiness which come only to the man who has found the work that he likes best.
# Perceiver IO quote:
# Success in its highest and noblest form calls for peace of mind and enjoyment and happiness which come only to the man who has found the work that he likes bost.
#
# Real quote:
# I trust that when people meet, we meet for a transcendent reason, and that the challenges we face in life are always lessons that serve our soul's growth.
# Perceiver IO quote:
# I trust that when people meet, we meet for a transcendent reason, and that the challenges we face in life are always lessons that serve our soul's geows .
#
# Real quote:
# To control the breathing is to control the mind. With different patterns of breathing, you can fall in love, you can hate someone, you can feel the whole spectrum of feelings just by changing your breathing.
# Perceiver IO quote:
# To control the breathing is to control the mind. With different patterns of breathing, you can fall in love, you can hate someone, you can feel the whole spectrum of feelings just by changing your mind  o  .
#
# Real quote:
# There's no art to find the mind's construction in the face.
# Perceiver IO quote:
# There's no art to find the mind's construction in the bodd.
#
# Real quote:
# Life is a series of punches. It presents a lot of challenges. It presents a lot of hardship, but the people that are able to take those punches and able to move forward are the ones that really do have a lot of success and have a lot of joy in their life and have a lot of stories to tell, too.
# Perceiver IO quote:
# Life is a series of punches. It presents a lot of challenges. It presents a lot of hardship, but the people that are able to take those punches and able to move forward are the ones that really do have a lot of success and have a lot of joy in their life and have a lot of stories to tell,
#
# Real quote:
# I said to my soul, be still, and wait without hope, For hope would be hope for the wrong thing.
# Perceiver IO quote:
# I said to my soul, be still, and wait without hope, For hope would be hope for the wrong to ng.
#
# Real quote:
# All of life and human relations have become so incomprehensibly complex that, when you think about it, it becomes terrifying and your heart stands still.
# Perceiver IO quote:
# All of life and human relations have become so incomprehensibly complex that, when you think about it, it becomes terrifying and your heart stands st it.
#
# Real quote:
# If you cannot inspire a woman with love of you, fill her above the brim with love of herself; all that runs over will be yours.
# Perceiver IO quote:
# If you cannot inspire a woman with love of you, fill her above the brim with love of herself; all that runs over will be goue .
#
# Real quote:
# The only thing I'm addicted to is winning. This bootleg cult, arrogantly referred to as Alcoholics Anonymous, reports a 5 percent success rate. My success rate is 100 percent.
# Perceiver IO quote:
# The only thing I'm addicted to is winning. This bootleg cult, arrogantly referred to as Alcoholics Anonymous, reports a 5 percent success rate. My success rate is 100 p   e t.
#
# Real quote:
# The hope of a secure and livable world lies with disciplined nonconformists who are dedicated to justice, peace and brotherhood.
# Perceiver IO quote:
# The hope of a secure and livable world lies with disciplined nonconformists who are dedicated to justice, peace and love o  ite.
#
# Real quote:
# When humor can be made to alternate with melancholy, one has a success, but when the same things are funny and melancholic at the same time, it's just wonderful.
# Perceiver IO quote:
# When humor can be made to alternate with melancholy, one has a success, but when the same things are funny and melancholic at the same time, it's just a   t  ae.
#
# Real quote:
# I think in art, but especially in films, people are trying to confirm their own existences.
# Perceiver IO quote:
# I think in art, but especially in films, people are trying to confirm their own ieeeeities.
#
# Real quote:
# The one you love and the one who loves you are never, ever the same person.
# Perceiver IO quote:
# The one you love and the one who loves you are never, ever the same pe yon.
#
# Real quote:
# A great social success is a pretty girl who plays her cards as carefully as if she were plain.
# Perceiver IO quote:
# A great social success is a pretty girl who plays her cards as carefully as if she were a may.
#
# Real quote:
# I love a massage. I'd go every day if I could. I don't need to be wrapped in herbs like a salmon fillet, but I do love a massage.
# Perceiver IO quote:
# I love a massage. I'd go every day if I could. I don't need to be wrapped in herbs like a salmon fillet, but I do love a mass ge.
#
# Real quote:
# I love to sing. Mostly about love and sex.
# Perceiver IO quote:
# I love to sing. Mostly about love and jon.
#
# Real quote:
# Art is the stored honey of the human soul, gathered on wings of misery and travail.
# Perceiver IO quote:
# Art is the stored honey of the human soul, gathered on wings of misery and seanise.
#
# Real quote:
# When I stand before God at the end of my life, I would hope that I would not have a single bit of talent left, and could say, 'I used everything you gave me'.
# Perceiver IO quote:
# When I stand before God at the end of my life, I would hope that I would not have a single bit of talent left, and could say, 'I used everything you gave me
#
# Real quote:
# In my first story, 'Mr. Mysterious & Company'... I was asked to take out some of the humor because editors were afraid reviewers would dismiss the book as a joke. Today, humor is enjoyed and no longer regarded as literary brummagem.
# Perceiver IO quote:
# In my first story, 'Mr. Mysterious & Company'... I was asked to take out some of the humor because editors were afraid reviewers would dismiss the book as a joke. Today, humor is enjoyed and no longer regarded as literary a  a     .
#
# Real quote:
# The new 'Joy' was needed for a number of reasons. Recent developments in nutrition and new ingredients were two of the major reasons for the revision. One of the other big reasons was America's new love for big flavors. Yay!
# Perceiver IO quote:
# The new 'Joy' was needed for a number of reasons. Recent developments in nutrition and new ingredients were two of the major reasons for the revision. One of the other big reasons was America's new love for big flavors.
#
# Real quote:
# Art begins with resistance - at the point where resistance is overcome. No human masterpiece has ever been created without great labor.
# Perceiver IO quote:
# Art begins with resistance - at the point where resistance is overcome. No human masterpiece has ever been created without great fore .
#
# Real quote:
# Flaming enthusiasm, backed up by horse sense and persistence, is the quality that most frequently makes for success.
# Perceiver IO quote:
# Flaming enthusiasm, backed up by horse sense and persistence, is the quality that most frequently makes for a codss.
#
# Real quote:
# When we meet real tragedy in life, we can react in two ways - either by losing hope and falling into self-destructive habits, or by using the challenge to find our inner strength. Thanks to the teachings of Buddha, I have been able to take this second way.
# Perceiver IO quote:
# When we meet real tragedy in life, we can react in two ways - either by losing hope and falling into self-destructive habits, or by using the challenge to find our inner strength. Thanks to the teachings of Buddha, I have been able to take this second
#
# Real quote:
# The thing about Mumbai is you go five yards and all of human existence is revealed. It's an incredible cavalcade of life, and I love that.
# Perceiver IO quote:
# The thing about Mumbai is you go five yards and all of human existence is revealed. It's an incredible cavalcade of life, and I love itat.

# %%
print("Perceiver IO accuracy on predicting missing word =", "{0:.0%}".format(correct/total_q))
# Out:
# Perceiver IO accuracy on predicting missing word = 35%
